# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y =make_moons(n_samples=1000,noise=0.2)

# %%
df = {'x1':x[:,0],'x2':x[:,1],'y':y}

# %%
dataset= pd.DataFrame(df)

# %%
dataset
# Out:
#            x1        x2  y
# 0    0.466090 -0.435082  1
# 1    0.194986  0.200977  1
# 2    0.102750 -0.171246  1
# 3    1.147080 -0.596854  1
# 4    2.425250 -0.114693  1
# ..        ...       ... ..
# 995 -0.722716  0.493593  0
# 996  0.950825  0.075558  1
# 997  1.953957  0.215898  1
# 998  0.329389  0.124743  1
# 999 -0.204639  1.105664  0
#
# [1000 rows x 3 columns]

# %%
sns.scatterplot(x=dataset["x1"],y=dataset["x2"],hue=dataset["y"])
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
x_a = dataset[["x1","x2"]]
x_a
# Out:
#            x1        x2
# 0    0.466090 -0.435082
# 1    0.194986  0.200977
# 2    0.102750 -0.171246
# 3    1.147080 -0.596854
# 4    2.425250 -0.114693
# ..        ...       ...
# 995 -0.722716  0.493593
# 996  0.950825  0.075558
# 997  1.953957  0.215898
# 998  0.329389  0.124743
# 999 -0.204639  1.105664
#
# [1000 rows x 2 columns]

# %%
y_a = dataset["y"]
y_a
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    0
# 996    1
# 997    1
# 998    1
# 999    0
# Name: y, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_a,y_a,train_size=0.3,random_state=43)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# bagging beta estimator
bg = BaggingClassifier(estimator=SVC(),n_estimators=30)# n_estimators = n0 0f models
bg.fit(x_train,y_train)
bg.score(x_train,y_train)*100, bg.score(x_test,y_test)*100
# Out:
# (96.66666666666667, 97.28571428571429)

# %%
rf = RandomForestClassifier(n_estimators=90)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)*100 , rf.score(x_test,y_test)*100
# Out:
# (100.0, 96.42857142857143)
